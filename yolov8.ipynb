# %% [markdown]
# <a href="https://colab.research.google.com/github/ThousandAI/yolov8/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.5/513.5 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 14.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Colab Notebooks/demo.jpg"
image = cv2.imread(path)
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
model = YOLO("yolov8x.pt")
results = model(new_image)
cv2.imwrite("yolov8_demo_x.jpg", results[0].plot())
# Out:
# ...
# 100%|██████████| 131M/131M [00:01<00:00, 112MB/s]
#
# 0: 448x640 3 persons, 2 cups, 1 chair, 1 dining table, 2 laptops, 1 book, 76.9ms
# Speed: 0.4ms preprocess, 76.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# True
